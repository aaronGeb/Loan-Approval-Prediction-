# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import accuracy_score,auc,roc_auc_score
from sklearn.tree import export_text
from sklearn.ensemble import RandomForestClassifier
from pandas import DataFrame
import pandas as pd
from typing import Optional

# %%
def load_data_to_dta_frame(filepath:str)->Optional[DataFrame]:
  '''
  Load a csv file to a pandas data frame
  Args:
      filepath: str: path to the csv file
  Returns:
       DataFrame: a pandas data frame
  '''
  try:
    return pd.read_csv(filepath)
  except FileNotFoundError:
    print(f'file not found at {filepath}')
    return None
df = load_data_to_dta_frame('../data/processed/credit_risk_dataset.csv')

# %%
df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0    3.135494      10.985310                  rent           4.820282
# 1    3.091042       9.169623                   own           1.791759
# 2    3.258097       9.169623              mortgage           0.693147
# 3    3.178054      11.089821                  rent           1.609438
# 4    3.218876      10.904138                  rent           2.197225
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    personal          d  10.463132       1.625226            1
# 1   education          b   6.908755       0.041636            0
# 2     medical          c   8.612685       0.603032            1
# 3     medical          c  10.463132       1.368866            1
# 4     medical          c  10.463132       1.057340            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0             0.463734                         y                    1.386294
# 1             0.095310                         n                    1.098612
# 2             0.451076                         n                    1.386294
# 3             0.425268                         n                    1.098612
# 4             0.438255                         y                    1.609438

# %%
df_full, df_test = train_test_split(df, test_size=0.2, random_state=42)
df_train, df_val = train_test_split(df_full, test_size=0.25, random_state=42)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train = df_train['loan_status']
y_val = df_val['loan_status']
y_test = df_test['loan_status']

# %%
del df_train['loan_status']
del df_val['loan_status']
del df_test['loan_status']

# %%
df_train.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0    3.178054      10.626121              mortgage           2.079442
# 1    3.218876      11.264477              mortgage           0.000000
# 2    3.891820      11.170506                  rent           1.791759
# 3    3.258097      10.491302              mortgage           1.098612
# 4    3.332205      10.942014                  rent           1.098612
#
#          loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 0          education          b   9.680406       0.265545
# 1  debtconsolidation          d   9.878221       1.394827
# 2           personal          b   9.680406      -0.571681
# 3  debtconsolidation          c   9.528867       0.716609
# 4    homeimprovement          d   9.546884       0.927538
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0             0.329304                         n                    1.098612
# 1             0.223144                         n                    1.609438
# 2             0.207014                         n                    2.890372
# 3             0.322083                         n                    1.609438
# 4             0.223144                         n                    2.197225

# %%
train_dict = df_train.to_dict(orient='records')

# %%
dv = DictVectorizer(sparse=False)

# %%
X_train = dv.fit_transform(train_dict)

# %%
dv.get_feature_names_out()
# Out:
# array(['cb_person_cred_hist_length', 'cb_person_default_on_file=n',
#        'cb_person_default_on_file=y', 'loan_amnt', 'loan_grade=a',
#        'loan_grade=b', 'loan_grade=c', 'loan_grade=d', 'loan_grade=e',
#        'loan_grade=f', 'loan_grade=g', 'loan_int_rate',
#        'loan_intent=debtconsolidation', 'loan_intent=education',
#        'loan_intent=homeimprovement', 'loan_intent=medical',
#        'loan_intent=personal', 'loan_intent=venture',
#        'loan_percent_income', 'person_age', 'person_emp_length',
#        'person_home_ownership=mortgage', 'person_home_ownership=other',
#        'person_home_ownership=own', 'person_home_ownership=rent',
#        'person_income'], dtype=object)

# %%
dt = DecisionTreeClassifier(criterion='entropy', max_depth=10,min_samples_leaf=1,min_samples_split=15)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=10, min_samples_split=15)

# %%
val_dict = df_val.to_dict(orient='records')
X_val = dv.transform(val_dict)

# %%
y_pred = dt.predict_proba(X_val)

# %%
roc_auc_score(y_val, y_pred[:,1])
# Out:
# 0.9126487057864963

# %%
y_pred = dt.predict_proba(X_train)
roc_auc_score(y_train, y_pred[:,1])
# Out:
# 0.9343041188375135

# %%
print(f"Training set class distribution: {y_train.value_counts()}")
print(f"Test set class distribution: {y_test.value_counts()}")
# Out:
# Training set class distribution: loan_status
# 0    15297
# 1     4251
# Name: count, dtype: int64
# Test set class distribution: loan_status
# 0    5072
# 1    1445
# Name: count, dtype: int64

# %%
print(export_text(dt, feature_names=dv.get_feature_names_out()))
# Out:
# |--- loan_percent_income <= 0.27
# |   |--- loan_int_rate <= 0.96
# |   |   |--- person_income <= 9.90
# |   |   |   |--- loan_percent_income <= 0.14
# |   |   |   |   |--- person_home_ownership=own <= 0.50
# |   |   |   |   |   |--- person_emp_length <= 0.35
# |   |   |   |   |   |   |--- loan_int_rate <= 0.62
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- loan_int_rate >  0.62
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- person_emp_length >  0.35
# |   |   |   |   |   |   |--- loan_intent=homeimprovement <= 0.50
# |   |   |   |   |   |   |   |--- person_income <= 9.43
# |   |   |   |   |   |   |   |   |--- loan_int_rate <= -1.08
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- loan_int_rate >  -1.08
# |   |   |   |   |   |   |   |   |   |--- person_income <= 9.08
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- person_income >  9.08
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- person_income >  9.43
# |   |   |   |   |   |   |   |   |--- person_emp_length <= 0.90
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- person_emp_length >  0.90
# |   |   |   |   |   |   |   |   |   |--- cb_person_cred_hist_length <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- cb_person_cred_hist_length >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- loan_intent=homeimprovement >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- person_home_ownership=own >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- loan_percent_income >  0.14
# |   |   |   |   |--- class: 1
# |   |   |--- person_income >  9.90
# |   |   |   |--- loan_grade=d <= 0.50
# |   |   |   |   |--- person_income <= 11.00
# |   |   |   |   |   |--- person_home_ownership=own <= 0.50
# |   |   |   |   |   |   |--- loan_intent=homeimprovement <= 0.50
# |   |   |   |   |   |   |   |--- loan_intent=venture <= 0.50
# |   |   |   |   |   |   |   |   |--- loan_grade=a <= 0.50
# |   |   |   |   |   |   |   |   |   |--- person_income <= 10.46
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- person_income >  10.46
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- loan_grade=a >  0.50
# |   |   |   |   |   |   |   |   |   |--- person_age <= 3.48
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- person_age >  3.48
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- loan_intent=venture >  0.50
# |   |   |   |   |   |   |   |   |--- loan_grade=c <= 0.50
# |   |   |   |   |   |   |   |   |   |--- loan_grade=e <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- loan_grade=e >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- loan_grade=c >  0.50
# |   |   |   |   |   |   |   |   |   |--- person_income <= 10.96
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- person_income >  10.96
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- loan_intent=homeimprovement >  0.50
# |   |   |   |   |   |   |   |--- person_age <= 3.20
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- person_age >  3.20
# |   |   |   |   |   |   |   |   |--- person_income <= 10.45
# |   |   |   |   |   |   |   |   |   |--- person_home_ownership=rent <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- person_home_ownership=rent >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- person_income >  10.45
# |   |   |   |   |   |   |   |   |   |--- person_home_ownership=rent <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- person_home_ownership=rent >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- person_home_ownership=own >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- person_income >  11.00
# |   |   |   |   |   |--- loan_grade=a <= 0.50
# |   |   |   |   |   |   |--- loan_grade=e <= 0.50
# |   |   |   |   |   |   |   |--- person_home_ownership=own <= 0.50
# |   |   |   |   |   |   |   |   |--- person_income <= 11.01
# |   |   |   |   |   |   |   |   |   |--- person_emp_length <= 2.25
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- person_emp_length >  2.25
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- person_income >  11.01
# |   |   |   |   |   |   |   |   |   |--- person_income <= 11.29
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- person_income >  11.29
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- person_home_ownership=own >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- loan_grade=e >  0.50
# |   |   |   |   |   |   |   |--- loan_intent=debtconsolidation <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- loan_intent=debtconsolidation >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- loan_grade=a >  0.50
# |   |   |   |   |   |   |--- loan_intent=venture <= 0.50
# |   |   |   |   |   |   |   |--- loan_int_rate <= -1.59
# |   |   |   |   |   |   |   |   |--- person_age <= 3.75
# |   |   |   |   |   |   |   |   |   |--- person_income <= 11.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- person_income >  11.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- person_age >  3.75
# |   |   |   |   |   |   |   |   |   |--- person_age <= 3.77
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- person_age >  3.77
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- loan_int_rate >  -1.59
# |   |   |   |   |   |   |   |   |--- person_income <= 11.39
# |   |   |   |   |   |   |   |   |   |--- person_income <= 11.36
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- person_income >  11.36
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- person_income >  11.39
# |   |   |   |   |   |   |   |   |   |--- loan_amnt <= 7.84
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- loan_amnt >  7.84
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- loan_intent=venture >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- loan_grade=d >  0.50
# |   |   |   |   |--- loan_intent=debtconsolidation <= 0.50
# |   |   |   |   |   |--- person_emp_length <= 1.24
# |   |   |   |   |   |   |--- person_home_ownership=rent <= 0.50
# |   |   |   |   |   |   |   |--- person_income <= 10.80
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- person_income >  10.80
# |   |   |   |   |   |   |   |   |--- loan_amnt <= 10.10
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- loan_amnt >  10.10
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- person_home_ownership=rent >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- person_emp_length >  1.24
# |   |   |   |   |   |   |--- loan_intent=medical <= 0.50
# |   |   |   |   |   |   |   |--- cb_person_default_on_file=y <= 0.50
# |   |   |   |   |   |   |   |   |--- loan_percent_income <= 0.22
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- loan_percent_income >  0.22
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- cb_person_default_on_file=y >  0.50
# |   |   |   |   |   |   |   |   |--- person_age <= 3.20
# |   |   |   |   |   |   |   |   |   |--- cb_person_cred_hist_length <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- cb_person_cred_hist_length >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- person_age >  3.20
# |   |   |   |   |   |   |   |   |   |--- person_emp_length <= 1.70
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- person_emp_length >  1.70
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- loan_intent=medical >  0.50
# |   |   |   |   |   |   |   |--- person_income <= 10.76
# |   |   |   |   |   |   |   |   |--- person_income <= 10.40
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- person_income >  10.40
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- person_income >  10.76
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- loan_intent=debtconsolidation >  0.50
# |   |   |   |   |   |--- person_home_ownership=own <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- person_home_ownership=own >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |--- loan_int_rate >  0.96
# |   |   |--- loan_grade=c <= 0.50
# |   |   |   |--- loan_intent=debtconsolidation <= 0.50
# |   |   |   |   |--- loan_intent=medical <= 0.50
# |   |   |   |   |   |--- person_emp_length <= 1.24
# |   |   |   |   |   |   |--- person_home_ownership=rent <= 0.50
# |   |   |   |   |   |   |   |--- loan_grade=g <= 0.50
# |   |   |   |   |   |   |   |   |--- person_income <= 9.88
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- person_income >  9.88
# |   |   |   |   |   |   |   |   |   |--- person_income <= 11.98
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- person_income >  11.98
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- loan_grade=g >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- person_home_ownership=rent >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- person_emp_length >  1.24
# |   |   |   |   |   |   |--- person_income <= 10.46
# |   |   |   |   |   |   |   |--- person_income <= 9.88
# |   |   |   |   |   |   |   |   |--- loan_percent_income <= 0.14
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- loan_percent_income >  0.14
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- person_income >  9.88
# |   |   |   |   |   |   |   |   |--- person_income <= 10.43
# |   |   |   |   |   |   |   |   |   |--- loan_intent=homeimprovement <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- loan_intent=homeimprovement >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- person_income >  10.43
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- person_income >  10.46
# |   |   |   |   |   |   |   |--- loan_grade=g <= 0.50
# |   |   |   |   |   |   |   |   |--- loan_grade=d <= 0.50
# |   |   |   |   |   |   |   |   |   |--- person_income <= 11.82
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- person_income >  11.82
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- loan_grade=d >  0.50
# |   |   |   |   |   |   |   |   |   |--- person_home_ownership=own <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- person_home_ownership=own >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- loan_grade=g >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- loan_intent=medical >  0.50
# |   |   |   |   |   |--- person_home_ownership=own <= 0.50
# |   |   |   |   |   |   |--- person_income <= 10.90
# |   |   |   |   |   |   |   |--- person_emp_length <= 1.24
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- person_emp_length >  1.24
# |   |   |   |   |   |   |   |   |--- person_age <= 3.20
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- person_age >  3.20
# |   |   |   |   |   |   |   |   |   |--- person_home_ownership=rent <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- person_home_ownership=rent >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- person_income >  10.90
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- person_home_ownership=own >  0.50
# |   |   |   |   |   |   |--- loan_grade=d <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- loan_grade=d >  0.50
# |   |   |   |   |   |   |   |--- person_income <= 10.16
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- person_income >  10.16
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- loan_intent=debtconsolidation >  0.50
# |   |   |   |   |--- person_home_ownership=own <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- person_home_ownership=own >  0.50
# |   |   |   |   |   |--- loan_grade=d <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- loan_grade=d >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |--- loan_grade=c >  0.50
# |   |   |   |--- person_income <= 9.88
# |   |   |   |   |--- loan_percent_income <= 0.15
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- loan_percent_income >  0.15
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- person_income >  9.88
# |   |   |   |   |--- person_income <= 11.28
# |   |   |   |   |   |--- person_home_ownership=own <= 0.50
# |   |   |   |   |   |   |--- loan_amnt <= 8.22
# |   |   |   |   |   |   |   |--- loan_percent_income <= 0.02
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- loan_percent_income >  0.02
# |   |   |   |   |   |   |   |   |--- loan_int_rate <= 1.06
# |   |   |   |   |   |   |   |   |   |--- person_age <= 3.48
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- person_age >  3.48
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- loan_int_rate >  1.06
# |   |   |   |   |   |   |   |   |   |--- loan_percent_income <= 0.14
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- loan_percent_income >  0.14
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- loan_amnt >  8.22
# |   |   |   |   |   |   |   |--- loan_percent_income <= 0.25
# |   |   |   |   |   |   |   |   |--- person_income <= 11.17
# |   |   |   |   |   |   |   |   |   |--- person_income <= 11.14
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- person_income >  11.14
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- person_income >  11.17
# |   |   |   |   |   |   |   |   |   |--- cb_person_cred_hist_length <= 2.56
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- cb_person_cred_hist_length >  2.56
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- loan_percent_income >  0.25
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- person_home_ownership=own >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- person_income >  11.28
# |   |   |   |   |   |--- loan_int_rate <= 1.06
# |   |   |   |   |   |   |--- person_age <= 3.75
# |   |   |   |   |   |   |   |--- person_emp_length <= 1.87
# |   |   |   |   |   |   |   |   |--- person_income <= 11.42
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- person_income >  11.42
# |   |   |   |   |   |   |   |   |   |--- person_income <= 11.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- person_income >  11.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- person_emp_length >  1.87
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- person_age >  3.75
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- loan_int_rate >  1.06
# |   |   |   |   |   |   |--- person_income <= 11.39
# |   |   |   |   |   |   |   |--- person_income <= 11.38
# |   |   |   |   |   |   |   |   |--- loan_int_rate <= 1.30
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- loan_int_rate >  1.30
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- person_income >  11.38
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- person_income >  11.39
# |   |   |   |   |   |   |   |--- class: 0
# |--- loan_percent_income >  0.27
# |   |--- person_home_ownership=rent <= 0.50
# |   |   |--- person_income <= 9.90
# |   |   |   |--- class: 1
# |   |   |--- person_income >  9.90
# |   |   |   |--- loan_int_rate <= 1.07
# |   |   |   |   |--- person_home_ownership=own <= 0.50
# |   |   |   |   |   |--- person_home_ownership=other <= 0.50
# |   |   |   |   |   |   |--- loan_grade=d <= 0.50
# |   |   |   |   |   |   |   |--- loan_int_rate <= 0.04
# |   |   |   |   |   |   |   |   |--- loan_intent=venture <= 0.50
# |   |   |   |   |   |   |   |   |   |--- person_income <= 10.99
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- person_income >  10.99
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- loan_intent=venture >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- loan_int_rate >  0.04
# |   |   |   |   |   |   |   |   |--- person_income <= 10.31
# |   |   |   |   |   |   |   |   |   |--- person_emp_length <= 0.35
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- person_emp_length >  0.35
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- person_income >  10.31
# |   |   |   |   |   |   |   |   |   |--- loan_percent_income <= 0.28
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- loan_percent_income >  0.28
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- loan_grade=d >  0.50
# |   |   |   |   |   |   |   |--- loan_intent=debtconsolidation <= 0.50
# |   |   |   |   |   |   |   |   |--- person_age <= 3.37
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- person_age >  3.37
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- loan_intent=debtconsolidation >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- person_home_ownership=other >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- person_home_ownership=own >  0.50
# |   |   |   |   |   |--- person_income <= 9.90
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- person_income >  9.90
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- loan_int_rate >  1.07
# |   |   |   |   |--- loan_intent=debtconsolidation <= 0.50
# |   |   |   |   |   |--- loan_intent=medical <= 0.50
# |   |   |   |   |   |   |--- loan_grade=g <= 0.50
# |   |   |   |   |   |   |   |--- cb_person_cred_hist_length <= 1.87
# |   |   |   |   |   |   |   |   |--- person_income <= 11.28
# |   |   |   |   |   |   |   |   |   |--- loan_int_rate <= 1.37
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- loan_int_rate >  1.37
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- person_income >  11.28
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- cb_person_cred_hist_length >  1.87
# |   |   |   |   |   |   |   |   |--- person_income <= 11.20
# |   |   |   |   |   |   |   |   |   |--- loan_percent_income <= 0.40
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- loan_percent_income >  0.40
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- person_income >  11.20
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- loan_grade=g >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- loan_intent=medical >  0.50
# |   |   |   |   |   |   |--- person_home_ownership=own <= 0.50
# |   |   |   |   |   |   |   |--- loan_grade=c <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- loan_grade=c >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- person_home_ownership=own >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- loan_intent=debtconsolidation >  0.50
# |   |   |   |   |   |--- person_home_ownership=own <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- person_home_ownership=own >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |--- person_home_ownership=rent >  0.50
# |   |   |--- class: 1

# %%
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [3, 5, 10,15, None],
    'min_samples_split': [2, 5, 10,15],
    'min_samples_leaf': [1, 2, 4,5],
    'max_features': [None, 'sqrt', 'log2'],
    'class_weight': [None, 'balanced']
}

# Define the GridSearch
grid_search = GridSearchCV(estimator=dt, param_grid=param_grid, 
                           cv=5, scoring='accuracy', n_jobs=-1, verbose=2)

# Fit the model
grid_search.fit(X_train, y_train)

# Print the best parameters
print("Best Parameters:", grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 960 candidates, totalling 4800 fits
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=2, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=5, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=5, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=5, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=5, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=5, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=5, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=5, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=5, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=5, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=None, min_samples_leaf=5, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=15; total time=   0.0s[CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
#
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=5; total time=   0.1s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=2; total time=   0.1s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=2, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=None, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=15; total time=   0.0s
# ...
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=5, min_samples_split=10; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=15; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=5, min_samples_split=2; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=5, min_samples_split=2; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=5, min_samples_split=2; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=2; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=5; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=5, min_samples_split=2; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=1, min_samples_split=15; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=5, min_samples_split=15; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=10; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=15; total time=   0.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# Best Parameters: {'class_weight': None, 'criterion': 'entropy', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 15}
